# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///TMDB.db

# %%
# %%sql
# Select * FROM Movies
# limit 5;
# Out:
#  * sqlite:///TMDB.db
# Done.
# [(5, 'Four Rooms', '1995-12-09 00:00:00.000000', 4000000, None, 'en', 'Four Rooms', "It's Ted the Bellhop's first night on the job...and the hotel's very unusual guests are about to place him in some outrageous predicaments. It seems that this evening's room service is serving up one unbelievable happening after another.", 22.87623, 4300000.0, 98.0, 'Released', "Twelve outrageous guests. Four scandalous requests. And one lone bellhop, in his first day on the job, who's in for the wildest New year's Eve of his life.", 6.5, 530),
#  (11, 'Star Wars', '1977-05-25 00:00:00.000000', 11000000, 'http://www.starwars.com/films/star-wars-episode-iv-a-new-hope', 'en', 'Star Wars', 'Princess Leia is captured and held hostage by the evil Imperial forces in their effort to take over the galactic Empire. Venturesome Luke Skywalker a ... (14 characters truncated) ... tain Han Solo team together with the loveable robot duo R2-D2 and C-3PO to rescue the beautiful princess and restore peace and justice in the Empire.', 126.393695, 775398007.0, 121.0, 'Released', 'A long time ago in a galaxy far, far away...', 8.1, 6624),
#  (12, 'Finding Nemo', '2003-05-30 00:00:00.000000', 94000000, 'http://movies.disney.com/finding-nemo', 'en', 'Finding Nemo', "Nemo, an adventurous young clownfish, is unexpectedly taken from his Great Barrier Reef home to a dentist's office aquarium. It's up to his worrisome ... (35 characters truncated) ... orgetful fish Dory to bring Nemo home -- meeting vegetarian sharks, surfer dude turtles, hypnotic jellyfish, hungry seagulls, and more along the way.", 85.688789, 940335536.0, 100.0, 'Released', "There are 3.7 trillion fish in the ocean, they're looking for one.", 7.6, 6122),
#  (13, 'Forrest Gump', '1994-07-06 00:00:00.000000', 55000000, None, 'en', 'Forrest Gump', "A man with a low IQ has accomplished great things in his life and been present during significant historic events - in each case, far exceeding what  ... (108 characters truncated) ... rest Gump' is the story of a man who rose above his challenges, and who proved that determination, courage, and love are more important than ability.", 138.133331, 677945399.0, 142.0, 'Released', "The world will never be the same, once you've seen it through the eyes of Forrest Gump.", 8.2, 7927),
#  (14, 'American Beauty', '1999-09-15 00:00:00.000000', 15000000, 'http://www.dreamworks.com/ab/', 'en', 'American Beauty', "Lester Burnham, a depressed suburban father in a mid-life crisis, decides to turn his hectic life around after developing an infatuation with his daughter's attractive friend.", 80.878605, 356296601.0, 122.0, 'Released', 'Look closer.', 7.9, 3313)]

# %%
from sqlalchemy import create_engine, MetaData, Table

# %% [markdown]
# ### Question 2: How many foreign keys do our tble languagemap have.

# %% [markdown]
# engine = create_engine('sqlite:///TMDB.db')
# metadata = MetaData()
# table_name = 'languagemap'
#
# # Reflect the table
# table = Table(table_name, metadata, autoload_with=engine)
#
# # Display foreign keys
# foreign_keys = table.foreign_keys
# for fk in foreign_keys:
#     print(f"Column: {fk.parent.name}, References: {fk.column.table.name}({fk.column.name})")

# %% [markdown]
# - for further inspection we do the following

# %%
# Reflect the languages table
languages_table = Table('languagemap', metadata, autoload_with=engine)
print(f"Foreign keys in 'languages': {[fk.parent.name for fk in languages_table.foreign_keys]}")

# Reflect the movies table
movies_table = Table('Movies', metadata, autoload_with=engine)
print(f"Foreign keys in 'movies': {[fk.parent.name for fk in movies_table.foreign_keys]}")
# Out:
# Foreign keys in 'languages': ['iso_639_1', 'movie_id']
# Foreign keys in 'movies': []

# %% [markdown]
# ### Creating Views

# %% [markdown]
# - view is a virtual table that is based on the result set of a query. Views do not store data themselves; instead, they display data stored in other tables.
# - There are two ways to achieve this and are highlighted below.

# %%
# %%sql
# //1
# CREATE VIEW Not_Released AS
# SELECT * FROM movies
# WHERE release_status != 'Released'
# Out:
#  * sqlite:///TMDB.db
# (sqlite3.OperationalError) near "/": syntax error
# [SQL: //1
# CREATE VIEW Not_Released AS
# SELECT * FROM movies
# WHERE release_status != 'Released']
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %%sql
# //2
# CREATE VIEW Not_Released2 AS
# SELECT * FROM movies
# WHERE release_status <> 'Released';
# Out:
#  * sqlite:///TMDB.db
# (sqlite3.OperationalError) near "/": syntax error
# [SQL: //2
# CREATE VIEW Not_Released2 AS
# SELECT * FROM movies
# WHERE release_status <> 'Released';]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# - notice you have to drop the view incase you waant to recret the view with the same name.
# - The code below is to verify if we have indeed created our view.

# %%
# %%sql
# SELECT * FROM Not_Released;
# Out:
#  * sqlite:///TMDB.db
# Done.
# [(40963, 'Little Big Top', '2006-01-01 00:00:00.000000', 0, None, 'en', 'Little Big Top', 'An aging out of work clown returns to his small hometown, resigned to spend the rest of his days in a drunken stupor. But when his passion for clowning is reawakened by the local amateur circus he finds his smile.', 0.0921, 0.0, 0.0, 'Rumored', None, 10.0, 1),
#  (43630, 'The Helix... Loaded', '2005-01-01 00:00:00.000000', 0, None, 'en', 'The Helix... Loaded', ' ', 0.0206, 0.0, 97.0, 'Rumored', None, 4.8, 2),
#  (50875, 'Higher Ground', '2011-08-26 00:00:00.000000', 2000000, 'http://www.sonyclassics.com/higherground/', 'en', 'Higher Ground', "A chronicle of one woman's lifelong struggle with her faith.", 1.699101, 841733.0, 109.0, 'Post Production', None, 5.3, 14),
#  (57294, 'Crying with Laughter', '2009-06-01 00:00:00.000000', 0, None, 'en', 'Crying with Laughter', 'Powerfully redemptive and darkly comedic revenge thriller set in the vicious world of stand-up comedy, starring Stephen McCole and Malcolm Shields.', 0.108135, 0.0, 93.0, 'Rumored', 'A Bad Trip Down Memory Lane', 7.0, 1),
#  (70875, 'The Harvest (La Cosecha)', '2011-07-29 00:00:00.000000', 56000, 'http://www.facebook.com/theharvestfilm', 'en', 'The Harvest (La Cosecha)', 'The story of the children who work 12-14 hour days in the fields without the protection of child labor laws. These children are not toiling in the fields in some far away land. They are working in America.', 0.010909, 0.0, 80.0, 'Rumored', None, 0.0, 0),
#  (84659, 'The Naked Ape', '2006-09-16 00:00:00.000000', 0, None, 'en', 'The Naked Ape', 'The Naked Ape is a coming-of-age film following three teenagers on a road trip across the Pacific Southwest.', 0.077577, 0.0, 110.0, 'Rumored', None, 5.0, 1),
#  (295886, 'Brotherly Love', '2015-04-24 00:00:00.000000', 1900000, None, 'en', 'Brotherly Love', 'West Philadelphia basketball star Sergio Taylor deals with the pressures of fame while his brother and sister have their own issues with ambition.', 1.367751, 0.0, 89.0, 'Post Production', None, 6.9, 21),
#  (357837, "Dancin' It's On", '2015-10-16 00:00:00.000000', 0, 'https://www.facebook.com/eastsidestorymovie', 'cs', "Dancin' It's On", "This coming of age Dance Film, in the spirit of Dirty Dancing, Karate Kid, and High School Musical - is about a young girl from Beverly Hills, Jennif ... (322 characters truncated) ... preparing for the contest, Jennifer and Ken must overcome scheming dance partners, a meddling father, and their own doubts for their love to prevail.", 0.186234, 0.0, 89.0, 'Post Production', "Dancin' Like You've Never Seen Before", 4.3, 2)]

# %%
# %%sql
# SELECT * FROM Not_Released2;
# Out:
#  * sqlite:///TMDB.db
# Done.
# [(40963, 'Little Big Top', '2006-01-01 00:00:00.000000', 0, None, 'en', 'Little Big Top', 'An aging out of work clown returns to his small hometown, resigned to spend the rest of his days in a drunken stupor. But when his passion for clowning is reawakened by the local amateur circus he finds his smile.', 0.0921, 0.0, 0.0, 'Rumored', None, 10.0, 1),
#  (43630, 'The Helix... Loaded', '2005-01-01 00:00:00.000000', 0, None, 'en', 'The Helix... Loaded', ' ', 0.0206, 0.0, 97.0, 'Rumored', None, 4.8, 2),
#  (50875, 'Higher Ground', '2011-08-26 00:00:00.000000', 2000000, 'http://www.sonyclassics.com/higherground/', 'en', 'Higher Ground', "A chronicle of one woman's lifelong struggle with her faith.", 1.699101, 841733.0, 109.0, 'Post Production', None, 5.3, 14),
#  (57294, 'Crying with Laughter', '2009-06-01 00:00:00.000000', 0, None, 'en', 'Crying with Laughter', 'Powerfully redemptive and darkly comedic revenge thriller set in the vicious world of stand-up comedy, starring Stephen McCole and Malcolm Shields.', 0.108135, 0.0, 93.0, 'Rumored', 'A Bad Trip Down Memory Lane', 7.0, 1),
#  (70875, 'The Harvest (La Cosecha)', '2011-07-29 00:00:00.000000', 56000, 'http://www.facebook.com/theharvestfilm', 'en', 'The Harvest (La Cosecha)', 'The story of the children who work 12-14 hour days in the fields without the protection of child labor laws. These children are not toiling in the fields in some far away land. They are working in America.', 0.010909, 0.0, 80.0, 'Rumored', None, 0.0, 0),
#  (84659, 'The Naked Ape', '2006-09-16 00:00:00.000000', 0, None, 'en', 'The Naked Ape', 'The Naked Ape is a coming-of-age film following three teenagers on a road trip across the Pacific Southwest.', 0.077577, 0.0, 110.0, 'Rumored', None, 5.0, 1),
#  (295886, 'Brotherly Love', '2015-04-24 00:00:00.000000', 1900000, None, 'en', 'Brotherly Love', 'West Philadelphia basketball star Sergio Taylor deals with the pressures of fame while his brother and sister have their own issues with ambition.', 1.367751, 0.0, 89.0, 'Post Production', None, 6.9, 21),
#  (357837, "Dancin' It's On", '2015-10-16 00:00:00.000000', 0, 'https://www.facebook.com/eastsidestorymovie', 'cs', "Dancin' It's On", "This coming of age Dance Film, in the spirit of Dirty Dancing, Karate Kid, and High School Musical - is about a young girl from Beverly Hills, Jennif ... (322 characters truncated) ... preparing for the contest, Jennifer and Ken must overcome scheming dance partners, a meddling father, and their own doubts for their love to prevail.", 0.186234, 0.0, 89.0, 'Post Production', "Dancin' Like You've Never Seen Before", 4.3, 2)]

# %%
# %%sql
# SELECT COUNT(*) AS item_count FROM Not_Released;
# Out:
#  * sqlite:///TMDB.db
# Done.
# [(8,)]

# %%
# %%sql
# SELECT COUNT(*) AS item_count FROM Not_Released2;
# Out:
#  * sqlite:///TMDB.db
# Done.
# [(8,)]

# %% [markdown]
# - querying more data from our view created.

# %%
# %%sql
# select title, release_date, release_status
# from Not_Released2;
# Out:
#  * sqlite:///TMDB.db
# Done.
# [('Little Big Top', '2006-01-01 00:00:00.000000', 'Rumored'),
#  ('The Helix... Loaded', '2005-01-01 00:00:00.000000', 'Rumored'),
#  ('Higher Ground', '2011-08-26 00:00:00.000000', 'Post Production'),
#  ('Crying with Laughter', '2009-06-01 00:00:00.000000', 'Rumored'),
#  ('The Harvest (La Cosecha)', '2011-07-29 00:00:00.000000', 'Rumored'),
#  ('The Naked Ape', '2006-09-16 00:00:00.000000', 'Rumored'),
#  ('Brotherly Love', '2015-04-24 00:00:00.000000', 'Post Production'),
#  ("Dancin' It's On", '2015-10-16 00:00:00.000000', 'Post Production')]

# %%
# %%sql
# create view released as
# select * from movies
# where release_status = 'Released';
# Out:
#  * sqlite:///TMDB.db
# Done.
# []

# %%
# %%sql
# drop view released2;
# Out:
#  * sqlite:///TMDB.db
# Done.
# []

# %%
# %%sql
# select count(*) as number_of_originals from released
# where title = original_title;
# Out:
#  * sqlite:///TMDB.db
# Done.
# [(4534,)]

# %%
# %%sql
# select * from released
# limit 2;
# Out:
#  * sqlite:///TMDB.db
# Done.
# [(5, 'Four Rooms', '1995-12-09 00:00:00.000000', 4000000, None, 'en', 'Four Rooms', "It's Ted the Bellhop's first night on the job...and the hotel's very unusual guests are about to place him in some outrageous predicaments. It seems that this evening's room service is serving up one unbelievable happening after another.", 22.87623, 4300000.0, 98.0, 'Released', "Twelve outrageous guests. Four scandalous requests. And one lone bellhop, in his first day on the job, who's in for the wildest New year's Eve of his life.", 6.5, 530),
#  (11, 'Star Wars', '1977-05-25 00:00:00.000000', 11000000, 'http://www.starwars.com/films/star-wars-episode-iv-a-new-hope', 'en', 'Star Wars', 'Princess Leia is captured and held hostage by the evil Imperial forces in their effort to take over the galactic Empire. Venturesome Luke Skywalker a ... (14 characters truncated) ... tain Han Solo team together with the loveable robot duo R2-D2 and C-3PO to rescue the beautiful princess and restore peace and justice in the Empire.', 126.393695, 775398007.0, 121.0, 'Released', 'A long time ago in a galaxy far, far away...', 8.1, 6624)]

# %% [markdown]
# - checking if the view exists:

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE type='view' AND name='released';
# Out:
#  * sqlite:///TMDB.db
# Done.
# [('released',)]

# %% [markdown]
# - How many movies no longer use they original name?

# %%
# %%sql
# select count(*) from released
# where title != original_title;
# Out:
#  * sqlite:///TMDB.db
# Done.
# [(261,)]

# %%
# %%sql
# select count(*) from movies
# where title != original_title;
# Out:
#  * sqlite:///TMDB.db
# Done.
# [(261,)]

# %%
# %%sql
# SELECT *
# FROM movies
# WHERE release_date > '2000-01-01'
#   AND budget > 100000000
# ORDER BY popularity DESC
# LIMIT 1;
# Out:
#  * sqlite:///TMDB.db
# Done.
# [(157336, 'Interstellar', '2014-11-05 00:00:00.000000', 165000000, 'http://www.interstellarmovie.net/', 'en', 'Interstellar', 'Interstellar chronicles the adventures of a group of explorers who make use of a newly discovered wormhole to surpass the limitations on human space travel and conquer the vast distances involved in an interstellar voyage.', 724.247784, 675120017.0, 169.0, 'Released', 'Mankind was born on Earth. It was never meant to die here.', 8.1, 10867)]

# %%
# %%sql
# SELECT COUNT(*) FROM movies
# WHERE original_language != 'en';
# Out:
#  * sqlite:///TMDB.db
# Done.
# [(298,)]

# %%
# %%sql
# SELECT COUNT(*) AS number_of_pixar_movies
# FROM Movies m
# JOIN ProductionCompanyMap p on m.movie_id = p.movie_id
# JOIN ProductionCompanies pc on p.production_company_id = pc.production_company_id
# WHERE pc.production_company_name = 'Pixar Animation Studios';
# Out:
#  * sqlite:///TMDB.db
# Done.
# [(16,)]

# %%
# %%sql
# select * from ProductionCompanies;
# Out:
#  * sqlite:///TMDB.db
# Done.
# [(1, 'Lucasfilm'),
#  (2, 'Walt Disney Pictures'),
#  (3, 'Pixar Animation Studios'),
#  (4, 'Paramount Pictures'),
#  (5, 'Columbia Pictures'),
#  (6, 'RKO Radio Pictures'),
#  (7, 'DreamWorks'),
#  (8, 'Fine Line Features'),
#  (9, 'Gaumont'),
#  (11, 'WingNut Films'),
#  (12, 'New Line Cinema'),
#  (13, 'Universal Studios'),
#  (14, 'Miramax Films'),
#  (18, 'Gracie Films'),
#  (23, 'Imagine Entertainment'),
#  (24, 'Mikona Productions GmbH & Co. KG'),
#  (27, 'DreamWorks SKG'),
#  (28, 'Newmarket Films'),
#  (30, 'Eddie Murphy Productions'),
#  (32, 'Buena Vista'),
#  (33, 'Universal Pictures'),
#  (34, 'Sony Pictures'),
#  (35, 'Lions Gate Films'),
#  (37, 'Gramercy Pictures'),
#  (41, 'Orion Pictures'),
#  (42, 'Universal Pictures Corporation'),
#  (43, 'Fox Searchlight Pictures'),
#  (44, 'Cruise/Wagner Productions'),
#  (46, 'WDR'),
#  (47, 'Constantin Film'),
#  (49, 'El Deseo'),
#  (53, 'Les Films du Carrosse'),
#  (54, 'The Independent Film Channel Productions'),
#  (56, 'Amblin Entertainment'),
#  (58, 'Sony Pictures Classics'),
#  (59, 'A Band Apart'),
#  (60, 'United Artists'),
#  (62, 'The Selznik Studio'),
#  (64, 'Les Productions Artistes AssociTs'),
#  (68, 'Big Primate Pictures'),
#  (69, 'MFPV Film'),
#  (70, 'American Zoetrope'),
#  (76, 'Zentropa Entertainments'),
#  (77, 'Milestone Productions'),
#  (79, 'Village Roadshow Pictures'),
#  (80, 'The Zanuck Company'),
#  (81, 'Plan B Entertainment'),
#  (82, 'Renn Productions'),
#  (83, 'France 2 CinTma'),
#  (84, 'Tree Line Films'),
#  (85, 'Konrad Pictures'),
#  (86, 'Catfish Productions'),
#  (88, 'Hawk Films'),
#  (97, 'Castle Rock Entertainment'),
#  (98, 'Detour Film Production'),
#  (100, 'Avon Production'),
#  (104, 'Canal Plus'),
#  (118, 'Det Danske Filminstitut'),
#  (119, 'Danmarks Radio (DR)'),
#  (120, 'Scorsese Productions'),
#  (125, 'Danish Film Institute'),
#  (126, 'Lakeshore Entertainment'),
#  (127, 'Screen Gems, Inc.'),
#  (129, 'Section Eight'),
#  (130, 'Jerry Bruckheimer Films'),
#  (134, 'Rogue Pictures'),
#  (135, 'UIP'),
#  (136, 'City Light Films'),
#  (145, 'Gaumont Columbia Tristar Films'),
#  (146, 'Handmade Films Ltd.'),
#  (147, 'FidTlitT Productions'),
#  (148, 'Gimages'),
#  (149, 'FOZ'),
#  (150, 'Headforce Ltd.'),
#  (152, 'Icon Productions'),
#  (156, 'Nordic Film'),
#  (157, 'SVT Drama'),
#  (158, 'Spyglass Entertainment'),
#  (159, 'Shady Acres Entertainment'),
#  (160, 'Pit Bull Productions'),
#  (161, 'Claussen + W÷bke Filmproduktion GmbH'),
#  (163, 'Revolution Films'),
#  (164, 'Rhombus Media'),
#  (171, 'Malpaso Productions'),
#  (172, 'NPV Entertainment'),
#  (174, 'Warner Bros. Pictures'),
#  (175, 'Caravan Pictures'),
#  (178, 'Ghoulardi Film Company'),
#  (179, 'The Magnolia Project'),
#  (181, 'Channel Four Films'),
#  (182, 'JVC Entertainment'),
#  (183, 'Le Studio Canal+'),
#  (185, 'Pandora Cinema'),
#  (186, 'Pyramide Productions'),
#  (191, 'Senator Film Produktion'),
#  (194, 'Hobby Films'),
#  (195, 'Pole Star'),
#  (200, 'Coraz=n International'),
#  (201, 'Arte'),
#  (204, 'Wnste Filmproduktion'),
#  (205, 'Mirage Entertainment'),
#  (206, 'Star Partners II Ltd.'),
#  (208, 'Bac Films'),
#  (209, 'Radiant Film GmbH'),
#  (210, 'Snddeutscher Rundfunk'),
#  (212, 'Infinity Features Entertainment'),
#  (213, "Cooper's Town Productions"),
#  (214, 'Eagle Vision Inc.'),
#  (215, 'Double Feature Films'),
#  (216, 'Jersey Films'),
#  (218, 'Rafran Cinematografica'),
#  (219, 'The Mirisch Corporation'),
#  (223, 'Les Films du Losange'),
#  (224, 'Wega Film'),
#  (225, 'BIM Distribuzione'),
#  (234, 'CoBo Fund'),
#  (235, 'Nordisk Film'),
#  (236, 'October Films'),
#  (240, 'Bazmark Films'),
#  (242, 'GF Studios AB'),
#  (245, 'Cowboy Films'),
#  (246, 'Film Council'),
#  (247, 'Granada Film Productions'),
#  (248, 'Impact Pictures'),
#  (250, 'Canal+Polska'),
#  (251, 'Avenue Pictures Productions'),
#  (254, 'Pandora Filmproduktion'),
#  (255, 'Paradis Films'),
#  (258, 'Scott Rudin Productions'),
#  (260, 'Heritage Films'),
#  (261, 'Samuel Goldwyn'),
#  (264, 'Studio Babelsberg'),
#  (265, 'Runteam Ltd.'),
#  (266, 'Agencja Produkcji Filmowej'),
#  (267, 'Beverly Detroit'),
#  (268, 'FilmFernsehFonds Bayern'),
#  (269, 'Filmboard Berlin-Brandenburg (FBB)'),
#  (270, 'Filmf÷rderanstalt (FFA)'),
#  (271, 'Mainstream S.A.'),
#  (278, 'Propaganda Films'),
#  (279, 'Single Cell Pictures'),
#  (280, 'CinTmaginaire Inc.'),
#  (282, 'Bookshop Productions'),
#  (283, 'Notting Hill Pictures'),
#  (284, 'DNA Films'),
#  (285, 'Live Entertainment'),
#  (286, 'Fantasy Films'),
#  (288, 'BBC Films'),
#  (289, 'Ingenious Film Partners'),
#  (290, 'Ingenious Media'),
#  (291, 'Perdido Prod.'),
#  (294, 'New Zealand Film Commission'),
#  (297, 'Aardman Animations'),
#  (299, 'Instituto Mexicano de Cinematograffa'),
#  (300, 'Alameda Films'),
#  (301, 'Cinecolor-MTxico'),
#  (303, 'Cinecolor-Argentina'),
#  (304, 'Artcam y Fonds Sud CinTma'),
#  (306, 'Twentieth Century Fox Film Corporation'),
#  (307, 'IFC Films'),
#  (308, 'The Weinstein Company'),
#  (310, 'Centre National de la CinTmatographie'),
#  (311, 'Procirep'),
#  (312, 'SoficinTma'),
#  (313, 'TS Productions'),
#  (315, 'Filmstiftung Nordrhein-Westfalen'),
#  (316, 'Wildwood Enterprises'),
#  (321, 'Memfis Film'),
#  (326, 'Laura Ziskin Productions'),
#  (328, 'TLA Releasing'),
#  (333, 'Original Film'),
#  (335, 'Tig Productions'),
#  (336, 'Wiedemann & Berg Filmproduktion'),
#  (337, 'Creado Film'),
#  (341, 'Silent Hill DCP Inc.'),
#  (342, 'Davis-Films'),
#  (343, 'Konami Corporation Ltd.'),
#  (345, 'O2 Filmes'),
#  (346, 'VideoFilmes'),
#  (347, 'Centropolis Entertainment'),
#  (348, 'Bedford Falls Productions'),
#  (349, 'Cruise-Wagner Productions'),
#  (353, 'Kino Vision'),
#  (354, 'Orly Films'),
#  (355, 'R.P. Productions'),
#  (356, 'TF1 Films Productions'),
#  (357, 'Vfa Digital'),
#  (358, 'Noel Gay Motion Picture Company'),
#  (359, 'Figment Films'),
#  (360, 'Geffen Pictures'),
#  (361, 'Blue Parrot Productions'),
#  (364, 'The Rank Organisation'),
#  (365, 'Nelson Entertainment'),
#  (367, 'Kemp Company'),
#  (368, 'Splendid Pictures'),
#  (369, 'Bungalow 78 Productions'),
#  (371, 'Cecchi Gori Group Tiger Cinematografica'),
#  (372, 'Groucho II Film Partnership'),
#  (373, 'Asymmetrical Productions'),
#  (375, 'Heineken Branded Entertainment'),
#  (376, 'Industry Entertainment'),
#  (379, 'Truth and Soul Pictures Inc'),
#  (380, 'Thousand Words'),
#  (381, 'Campanile Productions'),
#  (382, 'Newman-Foreman Productions'),
#  (384, 'MacDonald/Parkes Productions'),
#  (385, 'Stanley Kubrick Productions'),
#  (388, 'Horizon Pictures'),
#  (393, 'MACT Productions'),
#  (394, 'Videofilms'),
#  (395, 'Riofilm'),
#  (396, 'SLM Production Group'),
#  (398, 'Egg Films'),
#  (399, 'Show East'),
#  (406, 'Havoc'),
#  (407, 'Dreamland Productions'),
#  (412, 'Wendy Finerman Productions'),
#  (413, 'Proscenium Films'),
#  (414, 'Fountainbridge Films'),
#  (415, 'Laurence Mark Productions'),
#  (416, 'Python (Monty) Pictures Limited'),
#  (418, 'New South Wales Film & Television Office'),
#  (420, 'Marvel Studios'),
#  (421, 'Amen Ra Films'),
#  (423, 'Phantom Four'),
#  (427, 'PSO International'),
#  (429, 'DC Comics'),
#  (430, 'Lonely Film Productions GmbH & Co. KG.'),
#  (431, "Donners' Company"),
#  (433, 'Weed Road Pictures'),
#  (435, 'Di Bonaventura Pictures'),
#  (436, '1492 Pictures'),
#  (437, 'Heyday films'),
#  (441, 'Columbia Pictures Corporation'),
#  (443, 'Big Talk Productions'),
#  (444, 'Dune Entertainment'),
#  (445, 'Major Studio Partners'),
#  (446, 'Thinkfilm'),
#  (449, 'Virtual Studios'),
#  (450, 'Anarchos Productions'),
#  (455, 'Permut Presentations'),
#  (456, 'WCG Entertainment Productions'),
#  (457, 'Constellation Films'),
#  (458, 'Douglas/Reuther Productions'),
#  (462, 'Patalex IV Productions Limited'),
#  (463, 'Michael White Productions'),
#  (464, 'National Film Trustee Company'),
#  (465, 'Twickenham Film Studios'),
#  (467, 'Renaissance Pictures'),
#  (469, 'Hemdale Film Corporation'),
#  (470, 'Recorded Pictures Company'),
#  (472, 'Soprofilms'),
#  (473, 'TAO Film'),
#  (474, 'Yanco'),
#  (475, 'JD Productions'),
#  (476, 'Underworld Entertainment'),
#  (477, 'Hughes Entertainment'),
#  (480, 'Tobis'),
#  (485, 'Vinyl Films'),
#  (486, 'Portobello Pictures'),
#  (491, 'Summit Entertainment'),
#  (494, 'AVCO Embassy Pictures'),
#  (495, 'EDI'),
#  (496, 'David Foster Productions'),
#  (497, 'Revolution Studios'),
#  (498, 'Debra Hill Productions'),
#  (499, 'De Laurentiis Entertainment Group'),
#  (500, 'Goldcrest Films International'),
#  (501, 'Indo-British'),
#  (502, 'International Film Investors'),
#  (503, 'National Film Development Corporation of India'),
#  (504, 'Carolina Bank'),
#  (505, 'Cruel Productions'),
#  (506, 'Newmarket Capital Group'),
#  (507, 'Atlas Entertainment'),
#  (508, 'Regency Enterprises'),
#  (514, 'Silver Screen Partners'),
#  (516, 'Seven Arts Productions'),
#  (517, 'Allied Artists'),
#  (518, 'Transworld Pictures'),
#  (520, 'Pacific Data Images (PDI)'),
#  (521, 'DreamWorks Animation'),
#  (523, 'Camelot Productions'),
#  (524, 'Canal Plus Group'),
#  (525, 'Ixtlan Productions'),
#  (526, 'Roxlom Films'),
#  (528, 'Bandai Visual Company'),
#  (536, 'The Coppola Company'),
#  (538, 'EMI Films Ltd.'),
#  (539, 'Block 2 Pictures'),
#  (540, 'Jet Tone Production'),
#  (541, 'Famous Players Ltd'),
#  (542, 'Guardian Trust Company'),
#  (543, 'Filmplan International II'),
#  (545, 'Ten Thirteen Productions'),
#  (547, 'Open City Films'),
#  (549, 'Swanford Films'),
#  (551, 'Mandalay Pictures'),
#  (552, 'Dark Horse Entertainment'),
#  (553, 'Barclays Mercantile Industrial Finance'),
#  (554, 'Silver Screen Partners III'),
#  (559, 'TriStar Pictures'),
#  (560, 'Film Colony'),
#  (562, 'Appian Way'),
#  (563, 'Movieworld Productions'),
#  (564, 'Industrial Development Corporation of South Africa'),
#  (565, 'UK Film & TV Production Company'),
#  (566, 'National Film & Video Foundation of South Africa'),
#  (567, 'Office Kitano'),
#  (571, 'Highland Films'),
#  (572, 'New Amsterdam Entertainment'),
#  (574, 'Lightstorm Entertainment'),
#  (579, 'Alliance Communications'),
#  (582, 'Hachette PremiFre'),
#  (591, 'France 3 CinTma'),
#  (592, 'Claudie Ossard Productions'),
#  (594, 'Capella International'),
#  (595, "Eric's Boy"),
#  (596, 'KC Medien AG'),
#  (597, 'Irish Dreamtime'),
#  (598, 'Team Todd'),
#  (614, 'Vanguard Films'),
#  (616, 'Eskwad'),
#  (617, 'Brooksfilms Ltd.'),
#  (620, 'Centropolis Film Productions'),
#  (622, 'Toho Film (Eiga) Co. Ltd.'),
#  (631, 'Parkway Pictures (I)'),
#  (633, 'Metro Productions'),
#  (634, 'ABC Pictures'),
#  (635, 'Les Films Alain Sarde'),
#  (636, 'Babbo Inc.'),
#  (637, 'The Picture Factory'),
#  (638, 'Laurel Group'),
#  (644, 'Alcor Films'),
#  (646, "D'Antoni Productions"),
#  (649, 'Sony'),
#  (654, 'South Pacific Pictures'),
#  (655, 'Strike Entertainment'),
#  (656, 'Metropolitan Filmexport'),
#  (657, 'Toho-Towa'),
#  (658, 'MI 3 Film'),
#  (662, 'Turman-Foster Company'),
#  (664, 'City Film'),
#  (668, 'T.H.E. Films'),
#  (675, 'Forward Pass'),
#  (676, 'Monarchy Enterprises B.V.'),
#  (679, 'Timnick Films'),
#  (682, 'Peninsula Films'),
#  (685, 'Cineclick Asia'),
#  (686, 'Tiger Aspect Productions'),
#  (689, 'Ventanarosa Productions'),
#  (690, 'Handprint Entertainment'),
#  (691, 'Cappa Productions'),
#  (692, 'Sogecine'),
#  (694, 'StudioCanal'),
#  (695, 'Lee Daniels Entertainment'),
#  (696, 'Rogue Marble'),
#  (698, 'Scottish Screen'),
#  (702, '3L Filmproduktion GmbH'),
#  (703, 'Razor Film Produktion GmbH'),
#  (704, 'Initial Entertainment Group'),
#  (705, 'Spring Creek Productions'),
#  (707, 'Matador Pictures'),
#  (711, 'Fox 2000 Pictures'),
#  (713, 'Nu Image Entertainment'),
#  (716, 'Standard Film Company'),
#  (718, 'Arts Council of England'),
#  (720, 'Goldwyn Films'),
#  (722, 'Temple Hill Productions'),
#  (724, 'Beijing New Picture Film Co. Ltd.'),
#  (726, 'Haut et Court'),
#  (728, 'Kalkaska Productions'),
#  (729, 'Why Not Productions'),
#  (732, 'Mate Producciones S.A.'),
#  (734, 'Producers Circle'),
#  (735, 'Waverly Films'),
#  (737, 'Sidney Kimmel Entertainment'),
#  (738, 'Myriad Pictures'),
#  (739, 'Anomaly Entertainment'),
#  (740, 'MTM Cineteve'),
#  (741, 'Emotion Pictures'),
#  (744, 'Diaphana Films'),
#  (746, 'MTV Films'),
#  (748, 'Mosaic Media Group'),
#  (753, 'Nouvelles +ditions de Films (NEF)'),
#  (758, 'TV2 Danmark'),
#  (762, 'Mutual Film Company'),
#  (763, 'Intermedia Films'),
#  (766, 'Blue Tulip Productions'),
#  (768, 'Ghost House Pictures'),
#  (769, 'Destination Films'),
#  (770, 'Kingsgate Films'),
#  (771, 'Mandate Pictures'),
#  (773, 'Film Afrika'),
#  (774, 'Valkyrie Films'),
#  (778, 'Las Producciones del Escorpion'),
#  (779, 'Lucky Red'),
#  (780, 'Red Wagon Productions'),
#  (784, 'Himen=ptero'),
#  (785, 'Sociedad General de Cine S.A.'),
#  (787, '3 Arts Entertainment'),
#  (788, 'Bel Air Entertainment'),
#  (793, 'GalatTe Films'),
#  (794, 'Agi Orsi Productions'),
#  (795, 'Vans Off the Wall'),
#  (798, 'Samuel Goldwyn Company'),
#  (802, 'Egg Pictures'),
#  (803, 'Alliance Atlantis Communications'),
#  (804, 'Natural Nylon Entertainment'),
#  (805, 'Serendipity Point Films'),
#  (806, 'TTlTfilm Canada'),
#  (807, 'The Harold Greenberg Fund'),
#  (808, 'The Movie Network'),
#  (809, 'Union GTnTrale CinTmatographique'),
#  (810, 'Persistent Entertainment'),
#  (812, 'Deuce Three Productions'),
#  (813, 'DiNovi Pictures'),
#  (814, 'Isabella Films BV'),
#  (816, 'FilmEngine'),
#  (817, 'Katalyst Films'),
#  (818, 'Gimages 5'),
#  (819, 'Mars Films'),
#  (821, 'The Greenlight Fund'),
#  (822, 'Happinet Pictures'),
#  (823, 'Telepool'),
#  (824, 'Kopelson Entertainment'),
#  (826, 'Capitol Films'),
#  (827, 'VIP 3 Medienfonds'),
#  (828, 'Ultra Films'),
#  (829, 'Vertigo Entertainment'),
#  (830, 'Senator International'),
#  (831, 'Saturn Films'),
#  (838, 'Paramount Vantage'),
#  (839, 'Lou Yi Inc.'),
#  (840, 'Lawrence Gordon Productions'),
#  (842, 'GreeneStreet/SKE Films'),
#  (846, '2929 Productions'),
#  (850, 'Eurimages'),
#  (851, 'MEDIA Programme of the European Union'),
#  (854, 'Sofica Europacorp'),
#  (856, 'Wild Bunch'),
#  (859, 'Saga Film'),
#  (860, 'Celluloid Dreams'),
#  (862, 'The Kennedy/Marshall Company'),
#  (863, 'Mantarraya Producciones'),
#  (864, 'No Dream Cinema'),
#  (865, 'Motel Films'),
#  (866, 'PathT Renn Productions'),
#  (867, 'Anka Film'),
#  (869, 'Dee Gee Entertainment'),
#  (870, 'Tapestry Films'),
#  (871, 'British Screen'),
#  (877, 'Casey Silver Productions'),
#  (879, 'Out of the Blue... Entertainment'),
#  (881, 'Daiei Studios'),
#  (882, 'Toho Company'),
#  (886, 'Kinokompaniya CTB'),
#  (888, 'Overseas FilmGroup'),
#  (889, 'Outlaw Productions'),
#  (890, 'Cheyenne Enterprises'),
#  (892, 'Qwerty Films'),
#  (893, 'Stanley Kramer Productions'),
#  (897, 'Taurus Films'),
#  (902, 'AZL Productions KG'),
#  (903, 'David Brown Productions'),
#  (904, 'MFP Munich Film Partners'),
#  (905, 'Phase 1 Productions'),
#  (906, 'Revelations Entertainment'),
#  (907, 'Overbrook Films'),
#  (908, 'Mystery Clock Cinema'),
#  (915, 'Hollywood Pictures'),
#  (916, 'The Charlie Mopic Company'),
#  (919, 'Beacon Communications'),
#  (921, 'Next Wednesday Productions'),
#  (922, 'SenArt Films'),
#  (923, 'Legendary Pictures'),
#  (924, 'The Turman-Morrissey Company'),
#  (925, 'Nu Image Films'),
#  (927, 'Palace Pictures'),
#  (931, 'HAL Films'),
#  (932, 'Mirage Enterprises'),
#  (938, 'First Floor Features'),
#  (939, 'New Legacy'),
#  (945, 'Cheongeoram'),
#  (946, 'CJ Capital Investment'),
#  (959, 'IndieProd Company Productions'),
#  (961, 'Roger Birnbaum Productions'),
#  (963, 'Destiny'),
#  (964, 'Keith Barish Productions'),
#  (965, 'TAFT Entertainment Pictures'),
#  (966, 'Monarch Pictures'),
#  (969, 'Golden Harvest Pictures'),
#  (972, 'Current Entertainment'),
#  (973, 'Immortal Entertainment'),
#  (975, 'Gerber Pictures'),
#  (978, 'Across the River Productions'),
#  (979, 'Woods Entertainment'),
#  (980, 'The Glasgow Film Fund'),
#  (986, 'Degeto Film'),
#  (987, 'USA Films'),
#  (991, 'Totally Independent'),
#  (995, 'Cinerenta Medienbeteiligungs KG'),
#  (999, 'Belstar Productions'),
#  (1001, 'Solaris Film'),
#  (1003, 'Filmkameratene A/S'),
#  (1010, 'Marimark Productions'),
#  (1012, 'Parabolic Pictures'),
#  (1013, 'Stable Way Entertainment'),
#  (1014, 'Target Media Entertainment'),
#  (1020, 'Millenium Films'),
#  (1030, 'Magnolia Pictures'),
#  (1031, 'Filmazure'),
#  (1032, 'Pirol Stiftung'),
#  (1033, 'Victoires International'),
#  (1038, 'Bazelevs Production'),
#  (1039, 'Channel One Russia'),
#  (1040, 'TABBAK'),
#  (1044, 'Franton Production'),
#  (1049, 'Kasander Film Company'),
#  (1050, 'David LaChapelle Studios'),
#  (1051, 'HSI Productions'),
#  (1052, 'Darkfibre Entertainment Ltd.'),
#  (1053, 'Got Films'),
#  (1062, 'Boll Kino Beteiligungs GmbH & Co. KG'),
#  (1063, 'Brightlight Pictures'),
#  (1064, 'Herold Productions'),
#  (1066, 'Distant Horizons'),
#  (1070, 'Milagro Films'),
#  (1073, 'Gordon Company'),
#  (1075, 'Europa Corp'),
#  (1076, 'Apipoulan'),
#  (1088, 'Alcon Entertainment'),
#  (1089, 'Witt/Thomas Productions'),
#  (1092, 'Mockingbird Pictures'),
#  (1095, 'Portman Entertainment Group'),
#  (1101, 'BTsame Mucho Pictures'),
#  (1102, 'Producciones Anhelo'),
#  (1113, 'Les Films 21'),
#  (1115, 'M6 Films'),
#  (1138, 'Filmways Pictures'),
#  (1143, 'Sound for Film'),
#  (1153, 'Act III Communications'),
#  (1155, 'Incorporated Television Company'),
#  (1156, 'Conundrum Entertainment'),
#  (1157, 'Les CinTmas de la Zone'),
#  (1163, 'Larger Than Life Productions'),
#  (1168, 'Novo Arturo Films'),
#  (1171, 'Epsilon Motion Pictures'),
#  (1172, 'Hyde Park Films'),
#  (1173, 'Shopgirl'),
#  (1176, 'Lorimar Film Entertainment'),
#  (1178, 'PathT Pictures International'),
#  (1182, 'Telecinco'),
#  (1187, 'Michael London Productions'),
#  (1188, 'William Dozier Productions'),
#  (1189, 'Greenlawn Productions'),
#  (1197, 'Vortex'),
#  (1202, 'Nippon Film Development and Finance Inc.'),
#  (1204, 'Ascendant Pictures'),
#  (1205, 'Endgame Entertainment'),
#  (1206, 'Entertainment Manufacturing Company'),
#  (1207, 'Reeleyes Film'),
#  (1208, 'Rising Star'),
#  (1212, 'Empire Pictures'),
#  (1216, 'Dino de Laurentiis Cinematografica'),
#  (1218, 'The Film Consortium'),
#  (1219, 'Baby Cow Productions'),
#  (1224, 'Intrepid Pictures'),
#  (1225, 'One Race Productions'),
#  (1232, '2003 Productions'),
#  (1236, 'Mandalay Entertainment'),
#  (1246, 'River Road Entertainment'),
#  (1251, 'ARD'),
#  (1256, 'Producers Sales Organization'),
#  (1257, "Butcher's Run Productions"),
#  (1260, 'Synchronistic Pictures'),
#  (1261, 'Scala Productions'),
#  (1266, 'Octagon Films'),
#  (1267, 'Ecosse Films'),
#  (1268, 'Focus Films'),
#  (1269, 'Momentum Films'),
#  (1270, 'National Lottery'),
#  (1271, 'Pariah Entertainment Group'),
#  (1272, 'The First Channel'),
#  (1274, 'Clinica Estetico'),
#  (1280, 'Pacific Western'),
#  (1296, 'Crossbow Productions'),
#  (1297, 'Gruskoff/Venture Films'),
#  (1298, 'Jouer Limited'),
#  (1301, 'Joseph M. Singer Entertainment'),
#  (1302, 'Davis Entertainment'),
#  (1305, 'L.I.F.T. Production'),
#  (1307, 'Triangle Film Corporation'),
#  (1308, 'Wark Producing Corp.'),
#  (1309, 'Rainforest Films'),
#  (1311, 'The Asylum'),
#  (1314, 'Hammer Film Productions'),
#  (1315, 'Charles Chaplin Productions'),
#  (1316, 'Monterey Productions'),
#  (1317, 'Charles K. Feldman Group'),
#  (1323, 'Florin Productions'),
#  (1324, 'Jerome Hellman Productions'),
#  (1350, 'Parkway Productions'),
#  (1353, 'Hanna-Barbera Productions'),
#  (1360, 'Glass Eye Pix'),
#  (1363, 'Haft Entertainment'),
#  (1370, 'Castel Film Romania'),
#  (1380, 'Australian Film Finance Corporation'),
#  (1382, 'PolyGram Filmed Entertainment'),
#  (1390, 'Celador Productions'),
#  (1393, 'Tokyo Broadcasting System (TBS)'),
#  (1403, 'Franchise Pictures'),
#  (1419, 'Virgin'),
#  (1420, 'ContentFilm'),
#  (1422, 'Killer Films'),
#  (1423, 'Escape Artists'),
#  (1424, 'Ada Films'),
#  (1432, 'Republic Pictures'),
#  (1444, 'Cannon Group'),
#  (1445, 'Golan-Globus'),
#  (1450, 'Front Street Productions'),
#  (1464, 'Summer Knowledge LLC'),
#  (1470, 'Wild Bear Films'),
#  (1471, 'Archer Street Productions'),
#  (1472, 'Delux Productions'),
#  (1473, 'Depth of Field'),
#  (1483, 'Redeemable Features'),
#  (1484, 'Yorktown Productions'),
#  (1490, 'Kintop Pictures'),
#  (1497, 'Marianne Productions'),
#  (1504, 'Cinergi Pictures Entertainment'),
#  (1507, 'International Production Company'),
#  (1508, 'Wildgaze Films'),
#  (1512, 'John Wells Productions'),
#  (1514, 'Tim Burton Animation Company'),
#  (1515, 'Will Vinton Studios'),
#  (1519, 'A&B Producoes'),
#  (1522, 'Neal Street Productions'),
#  (1531, 'Smart Egg Pictures'),
#  (1533, 'Indigo Film'),
#  (1538, 'Comedy Central'),
#  (1539, 'Fuller Films'),
#  (1550, 'Evamere Entertainment'),
#  (1553, 'Selznick International Pictures'),
#  (1557, 'The Mark Gordon Company'),
#  (1560, 'Roth-Arnold Productions'),
#  (1561, 'Pegasus Film Partners'),
#  (1565, 'Avery Pix'),
#  (1566, 'Spanky Pictures'),
#  (1569, 'Yash Raj Films'),
#  (1584, 'ITC Entertainment'),
#  (1591, 'Rhino Films'),
#  (1600, 'Craven-Maddalena Films'),
#  (1601, 'Maven Entertainment'),
#  (1606, 'Brillstein-Grey Entertainment'),
#  (1607, 'Gold/Miller Productions'),
#  (1608, 'Wayans Bros. Entertainment'),
#  (1615, 'Fortissimo Films'),
#  (1616, 'Process Productions'),
#  (1617, 'Q Television'),
#  (1620, 'Nuyorican Productions'),
#  (1627, 'Maran Film'),
#  (1631, 'Raw Nerve'),
#  (1632, 'Lionsgate'),
#  (1633, 'Next Entertainment'),
#  (1643, 'First Independent Films'),
#  (1644, 'Largo Entertainment'),
#  (1645, 'Scott Free Productions'),
#  (1646, 'Trap-Two-Zero Productions'),
#  (1649, 'Reforma Films'),
#  (1656, 'Pangaea'),
#  (1666, 'Rh(ne-Alpes CinTma'),
#  (1668, 'Riff Raff Film Productions'),
#  (1677, 'Mediaset'),
#  (1683, 'Andell Entertainment'),
#  (1685, 'Hofflund/Polone'),
#  (1687, 'Korea Capital Investment'),
#  (1688, 'Moho Films'),
#  (1689, 'TSJ Entertainment'),
#  (1690, 'Samsung Venture Capital'),
#  (1691, 'Ilshin Capital Investments'),
#  (1692, 'Centurion Investment'),
#  (1693, 'Nina Saxon Film Design'),
#  (1700, 'Cherry Road Films LLC'),
#  (1702, 'Medusa Produzione'),
#  (1704, 'Bavaria Film'),
#  (1708, 'Starbucks Entertainment'),
#  (1711, 'Ognon Pictures'),
#  (1712, 'Odessa Films'),
#  (1718, 'Odyssey'),
#  (1727, 'Movision'),
#  (1755, 'Allied Filmmakers'),
#  (1756, 'Broadway Video'),
#  (1757, 'Mad Chance'),
#  (1765, 'Turner Pictures'),
#  (1766, 'Dieter Geissler Filmproduktion'),
#  (1778, 'Dentsu Inc.'),
#  (1779, 'Tokuma Shoten'),
#  (1782, 'Smoke House'),
#  (1783, 'Jaret Entertainment'),
#  (1784, 'Partizan'),
#  (1785, 'Likely Story'),
#  (1786, 'Dark Castle Entertainment'),
#  (1787, 'Central Cinema Company Film'),
#  (1804, 'North by Northwest Entertainment'),
#  (1807, 'Warwick Film Productions'),
#  (1809, 'IM Filmproduktion'),
#  (1810, 'Cosmic Pictures'),
#  (1811, 'FilmColony'),
#  (1819, 'Cinema 77'),
#  (1824, 'Gravier Productions'),
#  (1836, 'Contrafilm'),
#  (1838, 'Firm Films'),
#  (1840, 'Elevation Filmworks'),
#  (1843, 'Grand Army Entertainment'),
#  (1848, "Les Films d'Ici"),
#  (1854, 'Dan Films'),
#  (1861, 'Polish Brothers Construction'),
#  (1865, 'Zanuck/Brown Productions'),
#  (1867, 'Golden Mean'),
#  (1872, 'Bleiberg Entertainment'),
#  (1885, 'Silver Pictures'),
#  (1887, 'Lorimar Motion Pictures'),
#  (1894, 'Josephson Entertainment'),
#  (1898, 'B=rd Scannßn na h+ireann'),
#  (1903, 'Columbus 81 Productions'),
#  (1915, 'Becker International'),
#  (1916, 'Claraflora'),
#  (1917, 'EM Media'),
#  (1918, 'NorthSee'),
#  (1938, 'Scholastic Productions'),
#  (1947, 'New Deal Productions'),
#  (1950, 'New World Pictures'),
#  (1962, 'ATO Pictures'),
#  (1972, 'X-Filme Creative Pool'),
#  (1973, 'Three Strange Angels'),
#  (1974, 'Duplass Brothers Productions'),
#  (1975, 'Sneak Preview Entertainment'),
#  (1976, 'Film Science'),
#  (1980, 'Woodfall Film Productions'),
#  (1983, 'Grosvenor Park Films LLP'),
#  (1991, 'Motion Investment Group'),
#  (1992, 'La Petite Reine'),
#  (1993, 'TF 1 Film Productions'),
#  (1994, 'Tri Pictures'),
#  (1995, 'Sorolla Films'),
#  (1996, 'Novo RPI'),
#  (1997, 'Banques Populaire Image 7'),
#  (2009, 'Maipo Film- og TV Produksjon'),
#  (2015, 'Darlow Smithson Productions'),
#  (2019, 'Osiris Films'),
#  (2029, 'Estudios Picasso'),
#  (2030, 'Participant Productions'),
#  (2031, 'Playtone Production'),
#  (2051, 'Kinowelt Filmproduktion'),
#  (2053, 'Grosvenor Park Media Ltd.'),
#  (2054, 'Ruby Films'),
#  (2055, 'Skyline Films'),
#  (2061, 'Twisted Pictures'),
#  (2064, 'Lietuvos Kinostudija'),
#  (2065, 'Scout Productions'),
#  (2066, 'Zanagar Films'),
#  (2070, 'Rastar Pictures'),
#  (2073, 'Kadokawa Pictures'),
#  (2087, 'Blackfriars Bridge Films'),
#  (2088, 'NALA Films'),
#  (2089, 'Samuels Media'),
#  (2090, 'Motion Picture Corporation of America'),
#  (2092, 'Mike Zoss Productions'),
#  (2104, 'Tangled Web Productions'),
#  (2106, 'Saban Entertainment'),
#  (2108, 'Battleplan Productions'),
#  (2116, 'VIP Medienfonds 4'),
#  (2124, 'Melvin Simon Productions'),
#  (2130, 'Mr. Mudd Production'),
#  (2146, 'David Hamilton Productions'),
#  (2147, 'Echo Lake Productions'),
#  (2148, 'Flagship International'),
#  (2149, 'Noble Nomad Pictures'),
#  (2150, 'Greenestreet Films'),
#  (2152, 'GreeneStreet Films'),
#  (2154, 'Punch Productions'),
#  (2157, '26 Films'),
#  (2173, 'Great Oaks Entertainment'),
#  (2179, 'Collision Entertainment'),
#  (2180, 'Outerbanks Entertainment'),
#  (2184, 'Tollin/Robbins Productions'),
#  (2188, 'Artisan Entertainment'),
#  (2193, 'DoRo Fiction Film'),
#  (2195, 'Central-Europa Film'),
#  (2199, 'Horsepower Films'),
#  (2200, 'Liveplanet'),
#  (2201, 'Rickshaw Productions'),
#  (2203, 'Onyx Films'),
#  (2207, 'Montfort Producciones'),
#  (2213, 'Rainmaker Entertainment'),
#  (2214, 'Flower Films'),
#  (2216, 'Helkon Media AG'),
#  (2224, 'Plum Pictures'),
#  (2226, 'Media 8 Entertainment'),
#  (2227, 'True Grit Productions'),
#  (2229, 'Red Bank Films'),
#  (2230, 'MGM Television'),
#  (2231, 'Trilogy Entertainment Group'),
#  (2232, 'Cherry Alley Productions'),
#  (2233, 'Bristol Bay Productions'),
#  (2234, 'Baldwin Entertainment Group'),
#  (2235, 'Desertlands Entertainment'),
#  (2236, 'Maguire Entertainment'),
#  (2242, 'Everyman Pictures'),
#  (2243, 'Hammer & Tongs'),
#  (2245, 'Entertainment Films'),
#  (2246, 'Material Entertainment'),
#  (2248, 'A-Mark Entertainment'),
#  (2250, 'SCOPE Invest'),
#  (2251, 'Sony Pictures Animation'),
#  (2253, 'Lawrence Bender Productions'),
#  (2254, 'Egoli Tossell Film AG'),
#  (2257, 'Cracking the Earth Films'),
#  (2262, 'Silver Nitrate Films'),
#  (2264, 'Concert Promotion International'),
#  (2265, 'Shangri-La Entertainment'),
#  (2266, 'Bold Films'),
#  (2267, 'First Choice Films'),
#  (2268, 'Isle of Man Film'),
#  (2269, 'China Film Co-Production Corporation'),
#  (2270, 'China Film Group Corporation'),
#  (2273, 'Eden Rock Media'),
#  (2274, 'Element Films'),
#  (2278, 'EOS Entertainment'),
#  (2280, 'Les Films des Tournelles'),
#  (2281, 'Les Films de Beyrouth'),
#  (2282, 'Roissy Films'),
#  (2283, 'Sunnyland'),
#  (2290, 'Hunting Lane Films'),
#  (2291, 'Journeyman Pictures'),
#  (2292, 'Original Media'),
#  (2293, 'Silverwood Films'),
#  (2294, 'Traction Media'),
#  (2297, 'Class 5 Films'),
#  (2299, 'Wonderland Films'),
#  (2300, 'Key Creatives'),
#  (2306, 'Fontana Productions'),
#  (2307, "Hell's Kitchen Films"),
#  (2308, 'Type A Films'),
#  (2310, 'Screen West Midlands'),
#  (2313, 'Andrea Sperling Productions'),
#  (2315, 'Paramount Classics'),
#  (2318, "RTgion Provence C(te d'Azur"),
#  (2319, 'Flicks Motion Pictures'),
#  (2320, 'UTV Motion Pictures'),
#  (2322, 'The Javelina Film Company'),
#  (2325, 'Orsay Films'),
#  (2326, 'Autonomous'),
#  (2332, 'Bi-polar Pictures'),
#  (2335, 'Film 4'),
#  (2339, 'Access Films'),
#  (2340, 'Napoleon Pictures Limited'),
#  (2341, 'Belladonna Productions'),
#  (2343, 'Red Chillies Entertainment'),
#  (2345, 'Lemming Film'),
#  (2347, 'FGM Entertainment'),
#  (2348, 'Nickelodeon Movies'),
#  (2355, 'Hirsch'),
#  (2359, 'StTphan Films'),
#  (2361, 'Ad Hominem Enterprises'),
#  (2363, 'Cold Spring Pictures'),
#  (2364, 'The Montecito Picture Company'),
#  (2370, 'Merchant Ivory Productions'),
#  (2373, 'Patriot Pictures'),
#  (2376, 'Blueprint Pictures'),
#  (2377, 'Chicago Pacific Entertainment'),
#  (2378, 'Offspring Entertainment'),
#  (2379, 'Palladium Productions'),
#  (2391, 'Devonshire Productions'),
#  (2394, 'Artina Films'),
#  (2395, 'HanWay Films'),
#  (2397, 'Cohen/Pearl Productions'),
#  (2404, 'Yeah'),
#  (2406, 'Filmf÷rderung Hamburg'),
#  (2426, 'Les Films du Poisson'),
#  (2427, 'Zazen Produt)es'),
#  (2428, 'Wolper Organization'),
#  (2430, 'Est·dios Mega'),
#  (2432, 'Quanta Centro de Produt)es Cinematogrßficas'),
#  (2435, 'Langley Productions'),
#  (2439, 'Bee Vine Pictures'),
#  (2441, 'Fandango'),
#  (2448, 'Yari Film Group'),
#  (2452, 'UK Film Council'),
#  (2453, 'Lord of the Wind'),
#  (2454, 'Goldsmith-Thomas Productions'),
#  (2455, 'Red Om Films'),
#  (2458, 'Tartan Films'),
#  (2461, 'Chris Brinker Productions'),
#  (2471, 'National Geographic Society'),
#  (2478, 'Manhattan Project'),
#  (2481, 'Platinum Dunes'),
#  (2482, 'Dead Films'),
#  (2483, 'Laurel Entertainment'),
#  (2484, 'Golar Productions'),
#  (2490, 'LGM Productions'),
#  (2495, 'Lefwander Kapitalf÷rvaltning AB'),
#  (2499, 'The Kushner-Locke Company'),
#  (2506, 'Dreamachine'),
#  (2507, 'Todman, Simon, LeMasters Productions'),
#  (2510, 'Mundy Lane Entertainment'),
#  (2514, 'Alliance Films'),
#  (2516, 'Kuzui Enterprises'),
#  (2517, 'Avenging Conscience'),
#  (2519, 'DeBart'),
#  (2521, 'Golden Harvest Company'),
#  (2525, 'Avalanche Productions'),
#  (2526, 'Kickstart Productions'),
#  (2527, 'Marc Platt Productions'),
#  (2528, 'Top Cow Productions'),
#  (2531, 'Media Rights Capital'),
#  (2533, 'Albino Alligator Productions'),
#  (2537, 'Kennedy Miller Productions'),
#  (2539, 'Reaper Productions'),
#  (2546, 'Peirce Pictures'),
#  (2550, 'Teitler Film'),
#  (2554, 'Quincy Jones-David Salzman Entertainment'),
#  (2564, 'CinT@'),
#  (2568, 'Lunar Films'),
#  (2570, 'Bona Fide Productions'),
#  (2575, '21 Laps Entertainment'),
#  (2577, 'Studio 37'),
#  (2596, 'Jerry Weintraub Productions'),
#  (2598, 'Hasbro'),
#  (2599, 'Blue Askew'),
#  (2604, 'Mark Johnson Productions'),
#  (2605, 'Gran Via Productions'),
#  (2608, 'Happy Madison Productions'),
#  (2609, 'De Line Pictures'),
#  (2612, 'Les Productions du TrTsor'),
#  (2613, 'Futurikon'),
#  (2617, 'Ozla Pictures'),
#  (2630, 'Majestic Films International'),
#  (2632, 'Cinephil'),
#  (2636, 'Tag Entertainment'),
#  (2645, 'Guy Walks into a Bar Productions'),
#  (2646, 'Deep River Productions'),
#  (2648, 'Road Rebel'),
#  (2649, 'New Real Films'),
#  (2650, 'Ealing Studios'),
#  (2651, 'Fragile Films'),
#  (2655, 'Internationale Filmproduktion Richter'),
#  (2659, 'Starz Media'),
#  (2662, 'Trans-Film'),
#  (2673, 'La Fabrique de Films'),
#  (2674, 'Telecinco Cinema'),
#  (2675, 'La Parti Productions'),
#  (2679, 'FOTP Productions'),
#  (2680, 'Kurosawa Production Co.'),
#  (2683, 'Rai Cinema'),
#  (2689, '2 Entertain'),
#  (2690, 'Screen Yorkshire'),
#  (2691, 'Infinitum Nihil'),
#  (2699, 'Caviar Films'),
#  (2721, 'Jinks/Cohen Company'),
#  (2723, 'Lin Pictures'),
#  (2724, 'Abandon Entertainment'),
#  (2725, 'Foxtor Productions'),
#  (2726, 'Emperor Motion Pictures'),
#  (2727, 'Global Entertainment Group'),
#  (2728, 'Millbrook Pictures'),
#  (2729, 'Omnilab Media'),
#  (2730, 'Motown Productions'),
#  (2731, 'Intandem Films'),
#  (2735, 'Mid Atlantic Films'),
#  (2737, 'Davis-Panzer Productions'),
#  (2740, 'Jigsaw Productions'),
#  (2741, 'Falling Sky Entertainment'),
#  (2743, 'Astral Media'),
#  (2748, 'Clubdeal'),
#  (2752, 'DENTSU Music And Entertainment'),
#  (2755, 'Dante Entertainment'),
#  (2756, 'Vertigo Productions'),
#  (2760, 'Miracle Pictures'),
#  (2767, 'Mace Neufeld Productions'),
#  (2772, 'The Lab Of Madness'),
#  (2773, 'Broken Lizard Industries'),
#  (2776, 'MovieRoom Productions'),
#  (2777, 'Black & White Productions'),
#  (2779, 'Blue Star Pictures'),
#  (2780, 'Cube Vision'),
#  (2785, 'Warner Bros. Animation'),
#  (2787, 'Reel FX Creative Studios'),
#  (2795, 'Ott Medien'),
#  (2796, 'Wild West Picture Show Productions'),
#  (2798, 'Columbia Pictures Film Production Asia'),
#  (2800, 'AMC Pictures'),
#  (2802, 'TV4 Sweden'),
#  (2811, 'Neo Art & Logic'),
#  (2812, 'Lion Rock Productions'),
#  (2813, 'Forensic Films'),
#  (2814, 'Great Scott Productions Pty. Ltd.'),
#  (2822, 'SNL Studios'),
#  (2830, 'Rival Pictures'),
#  ...]
